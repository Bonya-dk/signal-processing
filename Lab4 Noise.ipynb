# %%
import os

os.path.exists('thinkdsp.py');

# %%
import numpy as np
import matplotlib.pyplot as plt

from thinkdsp import decorate

# %%
"""Exercise 1"""
# Out:
# 'Exercise 1'

# %%
os.path.exists('queue.wav');

# %%
from thinkdsp import read_wave

wave = read_wave("queue.wav")
wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
segment = wave.segment(start=6, duration=1.0)
segment.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spectrum = segment.make_spectrum()
spectrum.plot_power()
decorate(xlabel='Frequency (Hz)')

# %%
spectrum.plot_power()

loglog = dict(xscale='log', yscale='log')
decorate(xlabel='Frequency (Hz)', **loglog)

# %%
segment2 = wave.segment(start=2.5, duration=1.0)
segment2.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spectrum2 = segment2.make_spectrum()

spectrum.plot_power(alpha=0.5)
spectrum2.plot_power(alpha=0.5)
decorate(xlabel='Frequency (Hz)',
         ylabel='Amplitude')

# %%
spectrum.plot_power(alpha=0.5)
spectrum2.plot_power(alpha=0.5)
decorate(xlabel='Frequency (Hz)',
         ylabel='Amplitude',
         **loglog)

# %%
segment.make_spectrogram(512).plot(high=5000)
decorate(xlabel='Time(s)', ylabel='Frequency (Hz)')

# %%
from thinkdsp import Spectrum

def bartlett_method(wave, seg_length=512, win_flag=True):
    
    spectro = wave.make_spectrogram(seg_length, win_flag)
    spectrums = spectro.spec_map.values()
    
    psds = [spectrum.power for spectrum in spectrums]
    
    hs = np.sqrt(sum(psds) / len(psds))
    fs = next(iter(spectrums)).fs
    
    spectrum = Spectrum(hs, fs, wave.framerate)
    return spectrum

# %% [markdown]
# "bartlett_method makes a spectrogram and extracts spec_map, which maps from times to Spectrum objects. It computes the PSD for each spectrum, adds them up, and puts the results into a Spectrum object."

# %%
psd = bartlett_method(segment)
psd2 = bartlett_method(segment2)

psd.plot_power()
psd2.plot_power()

decorate(xlabel='Frequency (Hz)', 
         ylabel='Power', 
         **loglog)

# %%
os.path.exists('BTC_USD_2013-10-01_2020-06-12-CoinDesk.csv');

# %%
import pandas as pd

df = pd.read_csv('BTC_USD_2013-10-01_2020-06-12-CoinDesk.csv', 
                 parse_dates=[0])
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-308829dc4227> in <module>
# ----> 1 import pandas as pd
#       2
#       3 df = pd.read_csv('BTC_USD_2013-10-01_2020-06-12-CoinDesk.csv',
#       4                  parse_dates=[0])
#       5 df
#
# ModuleNotFoundError: No module named 'pandas'

# %%
ys = df['Closing Price (USD)']
ts = df.index

# %%
from thinkdsp import Wave

wave = Wave(ys, ts, framerate=1)
wave.plot()
decorate(xlabel='Time (days)')

# %% [markdown]
# I cannot solve this pandas problem, I tried to reinstall anaconda, istalled 32 bit and 64 bit, nothing works...
